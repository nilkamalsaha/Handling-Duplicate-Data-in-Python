# %% [markdown]
# ## 4. Duplicate Data Check

# %% [markdown]
# * Find any duplicate data
# * Deal with the duplicate data

# %%
import pandas as pd
alarm_survey = pd.read_excel('Alarm Survey Data.xlsx')

#duplicate rows in the DataFrame and returns a Boolean Series
alarm_survey.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428     True
# 6429     True
# 6430     True
# 6431     True
# 6432     True
# Length: 6433, dtype: bool

# %%
#return all duplicate rows

alarm_survey[alarm_survey.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [survey_id, age, number_of_children, activity_level, sleep_quality, number_of_snoozes, alarm_rating]
# Index: []

# %%
# Removes duplicate rows from the alarm_survey DataFrame and Modifies the original DataFrame in place

alarm_survey.drop_duplicates(inplace = True)

# %%
alarm_survey
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  light_activity            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  light_activity            1.0
# ...         ...  ...                 ...             ...            ...
# 6361       6362   27                 2.0          active            5.0
# 6362       6363   31                 1.0           light            4.0
# 6363       6364   26                 0.0  lightly active            5.0
# 6364       6365   27                 1.0          active            5.0
# 6365       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 0                     1      5 stars
# ...

# %%
# iloc: Stands for index location. It is used for purely integer-based indexing.
# 40:45: This slices rows from index 40 to 44 (Python slicing is exclusive of the end, so it stops before 45).
# : Selects all columns.

alarm_survey.iloc[40:45, :]
# Out:
#     survey_id  age  number_of_children  activity_level  sleep_quality  \
# 40         41   23                 0.0  lightly active            4.0
# 41         42   23                 0.0  lightly active            4.0
# 42         43   38                 3.0  lightly active            4.0
# 43         44   18                 0.0  lightly active            4.0
# 44         45   19                 0.0  light_activity            4.0
#
#     number_of_snoozes alarm_rating
# 40                  1      4 stars
# 41                  3      3 stars
# 42                  1      4 stars
# 43                  5      1 stars
# 44                  5      3 stars

# %%
alarm_survey.reset_index(drop = True, inplace = True)

# %%
alarm_survey.iloc[40:45, :]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0           light            3.0
# 2             3   18                 0.0  light_activity            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  light_activity            1.0
# ...         ...  ...                 ...             ...            ...
# 6361       6362   27                 2.0          active            5.0
# 6362       6363   31                 1.0           light            4.0
# 6363       6364   26                 0.0  lightly active            5.0
# 6364       6365   27                 1.0          active            5.0
# 6365       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes alarm_rating
# 0                     1      5 stars
# ...
